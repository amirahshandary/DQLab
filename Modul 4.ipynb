# %%
import numpy as np
import pandas as pd
import scipy as sc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#membaca csv
order_df = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/order.csv')

# %%
order_df.shape
# Out:
# (49999, 12)

# %%
print(f'kolom order df sebanyak: {order_df.shape[1]}')
# Out:
# kolom order df sebanyak: 12

# %%
print(f'baris order df sebanyak: {order_df.shape[0]}')
# Out:
# baris order df sebanyak: 49999

# %%
pd.set_option('display.max_rows',500)
order_df.head(100)
# Out:
#                             order_id  quantity  \
# 0   2e7a8482f6fb09756ca50c10d7bfc047         2
# 1   2e7a8482f6fb09756ca50c10d7bfc047         1
# 2   e5fa5a7210941f7d56d0208e4e071d35         1
# 3   3b697a20d9e427646d92567910af6d57         1
# 4   71303d7e93b399f5bcd537d124c0bcfa         1
# 5   be5bc2f0da14d8071e2d45451ad119d9         1
# 6   0a0837a5eee9e7a9ce2b1fa831944d27         1
# 7   1ff217aa612f6cd7c4255c9bfe931c8b         1
# 8   22613579f7d11cc59c4347526fc3c79e         1
# 9   356b492aba2d1a7da886e54e0b6212b7         1
# 10  35d3a51724a47ef1d0b89911e39cc4ff         1
# 11  36989eb07a0de2d3d3129eea35553875         1
# 12  36989eb07a0de2d3d3129eea35553875         2
# 13  39d0be719247e3b3a38846ba810197ea         1
# 14  3f72d2b757e725cd48a4726f831c7789         1
# 15  46046adea0e222a29259bad3d922fee8         1
# 16  4d66b3a9d12facad48a3b23cc9fe7898         1
# 17  50013835d7b14aefb452825864d3e414         1
# 18  51725d3e4bdfc97e28b40543310da8a3         1
# ...

# %%
order_df.tail(100)
# Out:
#                                order_id  quantity  \
# 49899  8375044308874af1c50719ecaee3786d         1
# 49900  842f178d66acea853df70a9be4cec244         1
# 49901  86af9599ffd64a39d743904daa8bdb2d         1
# 49902  8702ed75cfdc160f18e7e687371818f1         1
# 49903  87e3416e2de0152a60d621b4b22c8cc1         1
# 49904  8baf86c7fd7462703a46b07ed2c3c3c3         1
# 49905  90d40a4ca05ddfea558d94047c3de2e9         1
# 49906  913a3be1eecf771ac6f66727e2b9f312         2
# 49907  913a3be1eecf771ac6f66727e2b9f312         1
# 49908  91c506e966d7f684b4fa307b02341fcc         1
# 49909  92aac24381f1c7944500e5b66d70efa7         1
# 49910  9778cb541669139d06c5aaa454239be2         1
# 49911  97e11582eb8cdd7b83e35a4243d81f79         1
# 49912  98c8189ebf8816906dd9286580008261         1
# 49913  98fdd250e01c66e91a1a2632a6445039         1
# 49914  995daf9c525344acfdbc27f4da55f205         1
# 49915  9b14f66fe74131735be03b9f68dea3b2         1
# 49916  9b8759d21a6df9bc2d6f451c972674c4         1
# ...

# %%
#melihat null values
#kalau tidak pakai .sum() maka ...
#.to_frame().reset_index() untuk membuat tabel
nul_val = order_df.isnull().sum().to_frame().reset_index()
nul_val.columns = ['feature', 'jumlah_nul']
nul_val['pross_null%'] = nul_val.jumlah_nul/len(order_df)*100
nul_val
#ternyata yang paling banyak ada di product_weight_gram
# Out:
#                   feature  jumlah_nul  pross_null%
# 0                order_id           0     0.000000
# 1                quantity           0     0.000000
# 2              product_id           0     0.000000
# 3                   price           0     0.000000
# 4               seller_id           0     0.000000
# 5           freight_value           0     0.000000
# 6             customer_id           0     0.000000
# 7            order_status           0     0.000000
# 8           purchase_date           0     0.000000
# 9            payment_type           0     0.000000
# 10  product_category_name           0     0.000000
# 11    product_weight_gram          19     0.038001

# %% [markdown]
# # Pola data yang
#
# 1. numeric
#     - integer
#     - float
#     - complex
# 2. object/categoric
#     - count
#     - typo
#     - perbandingan

# %% [markdown]
# # Descriptive Statistics

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49999 entries, 0 to 49998
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               49999 non-null  object
#  1   quantity               49999 non-null  int64
#  2   product_id             49999 non-null  object
#  3   price                  49999 non-null  int64
#  4   seller_id              49999 non-null  object
#  5   freight_value          49999 non-null  int64
#  6   customer_id            49999 non-null  object
#  7   order_status           49999 non-null  object
#  8   purchase_date          49999 non-null  object
#  9   payment_type           49999 non-null  object
#  10  product_category_name  49999 non-null  object
#  11  product_weight_gram    49980 non-null  float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.6+ MB

# %%
#mengubah jenis data menjadi object saja
order_df.freight_value.astype('object')

#ada beberapa data dia terdeteksi object padahal dia numeric
# Out:
# 0         28000
# 1         45000
# 2        174000
# 3        154000
# 4        147000
#           ...
# 49994    172000
# 49995    130000
# 49996     14000
# 49997    108000
# 49998    189000
# Name: freight_value, Length: 49999, dtype: object

# %%
#untuk mencocokkan jenis data
order_df.head()
# Out:
#                            order_id  quantity  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047         2
# 1  2e7a8482f6fb09756ca50c10d7bfc047         1
# 2  e5fa5a7210941f7d56d0208e4e071d35         1
# 3  3b697a20d9e427646d92567910af6d57         1
# 4  71303d7e93b399f5bcd537d124c0bcfa         1
#
#                          product_id    price  \
# 0  f293394c72c9b5fafd7023301fc21fc2  1489000
# 1  c1488892604e4ba5cff5b4eb4d595400  1756000
# 2  f3c2d01a84c947b078e32bbef0718962  1707000
# 3  3ae08df6bcbfe23586dd431c40bddbb7  3071000
# 4  d2998d7ced12f83f9b832f33cf6507b6  3833000
#
#                           seller_id  freight_value  \
# 0  1554a68530182680ad5c8b042c3ab563          28000
# 1  1554a68530182680ad5c8b042c3ab563          45000
# 2  a425f92c199eb576938df686728acd20         174000
# 3  522620dcb18a6b31cd7bdf73665113a9         154000
# 4  25e6ffe976bd75618accfe16cefcbd0d         147000
#
#                         customer_id order_status purchase_date  \
# ...

# %%
#memisahkan numeric dan categoric
#numeric saja
#order_df.describe(.columns.tolist()
col_num = [*order_df.describe().columns]
order_df.describe()
# Out:
#            quantity         price  freight_value  product_weight_gram
# count  49999.000000  4.999900e+04   49999.000000         49980.000000
# mean       1.197484  2.607784e+06  104521.390428          2201.830892
# std        0.722262  1.388312e+06   55179.844962          3929.896875
# min        1.000000  2.000000e+05    9000.000000            50.000000
# 25%        1.000000  1.410500e+06   57000.000000           300.000000
# 50%        1.000000  2.610000e+06  104000.000000           800.000000
# 75%        1.000000  3.810000e+06  152000.000000          1850.000000
# max       21.000000  5.000000e+06  200000.000000         40425.000000

# %%
#col catagoric
order_df.describe(include = 'object')
# Out:
#                                 order_id                        product_id  \
# count                              49999                             49999
# unique                             42694                             16866
# top     8272b63d03f5f79c56e9e4120aec44ef  99a4788cb24856965c36a24e339b6058
# freq                                  21                               366
#
#                                seller_id                       customer_id  \
# count                              49999                             49999
# unique                              1777                             42694
# top     4a3ca9315b744ce9f8e9374361493884  fc3d1daec319d62d49bfb5e1f83123e9
# freq                                1236                                21
#
#        order_status purchase_date     payment_type product_category_name
# count         49999         49999            49999                 49999
# ...

# %%
#all
order_df.describe(include = 'all')
# Out:
#                                 order_id      quantity  \
# count                              49999  49999.000000
# unique                             42694           NaN
# top     8272b63d03f5f79c56e9e4120aec44ef           NaN
# freq                                  21           NaN
# mean                                 NaN      1.197484
# std                                  NaN      0.722262
# min                                  NaN      1.000000
# 25%                                  NaN      1.000000
# 50%                                  NaN      1.000000
# 75%                                  NaN      1.000000
# max                                  NaN     21.000000
#
#                               product_id         price  \
# count                              49999  4.999900e+04
# unique                             16866           NaN
# top     99a4788cb24856965c36a24e339b6058           NaN
# freq                                 366           NaN
# ...

# %%
#categori
order_df.describe(include = 'object')
# Out:
#                                 order_id                        product_id  \
# count                              49999                             49999
# unique                             42694                             16866
# top     8272b63d03f5f79c56e9e4120aec44ef  99a4788cb24856965c36a24e339b6058
# freq                                  21                               366
#
#                                seller_id                       customer_id  \
# count                              49999                             49999
# unique                              1777                             42694
# top     4a3ca9315b744ce9f8e9374361493884  fc3d1daec319d62d49bfb5e1f83123e9
# freq                                1236                                21
#
#        order_status purchase_date     payment_type product_category_name
# count         49999         49999            49999                 49999
# ...

# %% [markdown]
# # Mean Median Mode

# %%
#mean price
order_df.price.mean()
np.mean(order_df.price)
# Out:
# 2607783.9156783135

# %%
#mean 
order_df.mean()
np.mean(order_df)
# Out:
# quantity               1.197484e+00
# price                  2.607784e+06
# freight_value          1.045214e+05
# product_weight_gram    2.201831e+03
# dtype: float64

# %%
order_df.loc[:100,"price"].mean()
# Out:
# 2581000.0

# %%
#median
order_df.price.mean()
# Out:
# 2607783.9156783135

# %%
order_df.freight_value.median()
# Out:
# 104000.0

# %%
np.median(order_df)

# %%
#mode
order_df.product_category_name.mode()
# Out:
# 0    toys
# dtype: object

# %%
#memilih yang ada value toys saja
t = order_df.product_category_name == 'toys'
order_df[t]
# Out:
#                                order_id  quantity  \
# 2      e5fa5a7210941f7d56d0208e4e071d35         1
# 6      0a0837a5eee9e7a9ce2b1fa831944d27         1
# 16     4d66b3a9d12facad48a3b23cc9fe7898         1
# 22     60762802b48bb6d256d55b013d115013         1
# 31     985db56d4cabd2577d0960194dd2cd5a         1
# ...                                 ...       ...
# 49958  c5ee9eb8e2d188b9972722e4d5300390         1
# 49960  c629fd3aa69824b58230aee97ab8930d         1
# 49962  c7575bc6637b30826bd659a47a475a03         1
# 49966  cc82b75db7d018c137b470d668b91996         1
# 49992  e821c71ba6efed0813bbc0a01a95f24d         1
#
#                              product_id    price  \
# 2      f3c2d01a84c947b078e32bbef0718962  1707000
# 6      583916a5dae918f5e89baec139141c54  4489000
# 16     0c5801458e74f9b6c23b44c331426e30   378000
# 22     eba7488e1c67729f045ab43fac426f2e   983000
# 31     062619359d5f9a664606cb2a6ccb477a  4216000
# ...                                 ...      ...
# ...

# %% [markdown]
# # Mengenal dan Membuat Distribusi Data dengan Histogram

# %%
#membagi data categoric dan numeric
col_num = [*order_df.describe().columns]
